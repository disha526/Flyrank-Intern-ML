# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/disha526/ML-WEEK1/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# ## One row = one page (content_id), belonging to one client (client_id). Most metrics (impressions_90d, clicks_90d, etc.) are totals accumulated over the last 90 days — a snapshot, not an event log. Separately, impressions_last_30d vs impressions_prev_30d split the most recent 30 days from the prior 30 days, which is what lets you detect direction of change (declining/growing) instead of just a static total

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv('content_refresh_anonymized.csv')

# Verify grain: is one row really one content_id?
dupe_check = df.groupby('content_id').size()
print('Max rows per content_id:', dupe_check.max())
print('content_ids with more than 1 row:', (dupe_check > 1).sum())

print('Unique client_ids:', df['client_id'].nunique())

# Check whether last_30d + prev_30d line up with the 90d total
print(df[['impressions_90d', 'impressions_last_30d', 'impressions_prev_30d']].head())
# Out:
# Max rows per content_id: 1
# content_ids with more than 1 row: 0
# Unique client_ids: 32
#    impressions_90d  impressions_last_30d  impressions_prev_30d
# 0             3803                   578                   987
# 1            15320                  2501                  5915
# 2            12581                  2382                  6089
# 3            11751                  3626                  4206
# 4            19140                  4211                  6452

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
